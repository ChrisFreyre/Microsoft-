# %% [markdown]
# # Main DataFrame

# %% [markdown]
# ### Here we will clean all data supplied so we can have a accurate dataframe for our future recomendations.

# %% [markdown]
# # 1st:Data Frame: TITLES

# %%
#FILES NAMES
# !ls
# Out:
# 1st_Recommendation.ipynb  Movie Ratings.ipynb       imdb.title.basics.csv
# 2nd_recommendaX.ipynb     Options.ipynb             imdb.title.basics.csv.gz
# 2nd_recommendation.ipynb  Spread data               imdb.title.ratings.csv.gz
# FIX gross.ipynb           Titles details.ipynb      main_data.ipynb
# FIX movie titles.ipynb    bom.movie_gross.csv       mix data 1 y 2.ipynb
# Gross.ipynb               bom.movie_gross.csv.gz    top_studios.csv
# Main_Data.csv             graph_genre.csv

# %%
#OPEN WITH PANDAS AS PD
#ADD VARIABLE TO THE FILE ADDED
#OPEN FILE FOR TITLES
import pandas as pd
csv_movie_titles = "./imdb.title.basics.csv"
movies = pd.read_csv(csv_movie_titles)

# %%
#PRINT FILES HEAD
movies.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#PRINT INFO OF FILE
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#DATA FRAME OF MOVIES
movies
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#COPY OF DATA FRAME MOVIE INTO MOVIES1
movies1 = movies.copy()
movies1
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#COLUMNS OF DATA FRAME
movies1.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
#DROPPING RUN TIME MINUTES COLUMN
columns_to_drop = ['runtime_minutes','original_title']
0
movies1
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#COPY OF THE DATA FRAME MOVIES2
movies2 = movies1.copy()

# %%
#CHECKING DUPLICATES IN COLUMN PRIMARY TITLE
len(set(movies2["primary_title"]))
# Out:
# 136071

# %%
#DROP ALL DUPLICATES IN COLUMN PRIMARY TITLE
movies2.drop_duplicates(subset="primary_title", keep='first', inplace=True)
movies2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# # 2nd:Data Frame: GROSS

# %%
#FILES NAMES
# !ls
# Out:
# 1st_Recommendation.ipynb  Movie Ratings.ipynb       imdb.title.basics.csv
# 2nd_recommendaX.ipynb     Options.ipynb             imdb.title.basics.csv.gz
# 2nd_recommendation.ipynb  Spread data               imdb.title.ratings.csv.gz
# FIX gross.ipynb           Titles details.ipynb      main_data.ipynb
# FIX movie titles.ipynb    bom.movie_gross.csv       mix data 1 y 2.ipynb
# Gross.ipynb               bom.movie_gross.csv.gz    top_studios.csv
# Main_Data.csv             graph_genre.csv

# %%
#OPEN WITH PANDAS AS PD
#ADD VARIABLE TO THE FILE ADDED
#OPEN FILE
import pandas as pd
csv_movie_gross = "./bom.movie_gross.csv"
gross = pd.read_csv(csv_movie_gross)

# %%
#PRINT FILES HEAD
gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#PRINT INFO OF FILE
gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#DATA FRAME OF GROSS
gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#COPY DATA FRAME INTO GROSS1
gross1 = gross.copy()
gross1
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#COLUMNES OF DATA FRAME
gross1.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
#CHANGE NAME OF COLUMN
gross1["primary_title"] = gross1.pop("title")
gross1.columns
# Out:
# Index(['studio', 'domestic_gross', 'foreign_gross', 'year', 'primary_title'], dtype='object')

# %%
#DUPLICATE DATA FRAME GROSS2
gross2 = gross1.copy()

# %%
#CHECKING DUPLICATES IN COLUMN PRIMARY TITLE
len(set(gross2["primary_title"]))
# Out:
# 3386

# %%
#DROPPING DUPLICATES IN COLUMN PRIMARY TITLE
gross2.drop_duplicates(subset="primary_title", keep='first', inplace=True)
gross2
# Out:
#           studio  domestic_gross foreign_gross  year  \
# 0             BV     415000000.0     652000000  2010
# 1             BV     334200000.0     691300000  2010
# 2             WB     296000000.0     664300000  2010
# 3             WB     292600000.0     535700000  2010
# 4           P/DW     238700000.0     513900000  2010
# ...          ...             ...           ...   ...
# 3382       Magn.          6200.0           NaN  2018
# 3383          FM          4800.0           NaN  2018
# 3384        Sony          2500.0           NaN  2018
# 3385  Synergetic          2400.0           NaN  2018
# 3386       Grav.          1700.0           NaN  2018
#
#                                     primary_title
# 0                                     Toy Story 3
# 1                      Alice in Wonderland (2010)
# 2     Harry Potter and the Deathly Hallows Part 1
# 3                                       Inception
# 4                             Shrek Forever After
# ...

# %% [markdown]
# # 1st:Merge: Data Frame of Movies and Gross

# %% [markdown]
# ### DF_GROSS_TITLE

# %%
#MERGE DATA FRAME MOVIES2 WITH GROSS2 BY PRIMARY TITLE
df_gross_movies = pd.merge(movies2,gross2, on = "primary_title")
df_gross_movies
# Out:
#          tconst                    primary_title  \
# 0     tt0315642                            Wazir
# 1     tt0337692                      On the Road
# 2     tt0359950  The Secret Life of Walter Mitty
# 3     tt0365907      A Walk Among the Tombstones
# 4     tt0369610                   Jurassic World
# ...         ...                              ...
# 2600  tt8404272           How Long Will I Love U
# 2601  tt8427036                  Helicopter Eela
# 2602  tt8851262                     Spring Fever
# 2603  tt9078374                      Last Letter
# 2604  tt9151704        Burn the Stage: The Movie
#
#                        original_title  start_year  runtime_minutes  \
# 0                               Wazir        2016            103.0
# 1                         On the Road        2012            124.0
# 2     The Secret Life of Walter Mitty        2013            114.0
# 3         A Walk Among the Tombstones        2014            114.0
# ...

# %%
#NO MORE DUPLICATES IN TCONST OR PRIMARY TITLE
len(set(df_gross_movies["tconst"]))
# Out:
# 2605

# %% [markdown]
# # 2nd:Merge: DF_Gross_Movies and Rating

# %% [markdown]
# ### DF_GROSS_MOVIES_RATING

# %% [markdown]
# # 3rd:Rating Data Frame

# %%
# !ls
# Out:
# 1st_Recommendation.ipynb  Movie Ratings.ipynb       imdb.title.basics.csv
# 2nd_recommendaX.ipynb     Options.ipynb             imdb.title.basics.csv.gz
# 2nd_recommendation.ipynb  Spread data               imdb.title.ratings.csv.gz
# FIX gross.ipynb           Titles details.ipynb      main_data.ipynb
# FIX movie titles.ipynb    bom.movie_gross.csv       mix data 1 y 2.ipynb
# Gross.ipynb               bom.movie_gross.csv.gz    top_studios.csv
# Main_Data.csv             graph_genre.csv

# %%
#OPEN WITH PANDAS AS PD
#ADD VARIABLE TO THE FILE ADDED
#OPEN FILE
import pandas as pd
csv_movie_rating = "./imdb.title.ratings.csv.gz"
rating = pd.read_csv(csv_movie_rating)

# %%
#PRINT FILES HEAD
rating.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#PRINT INFO OF FILE
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
rating
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#CHECKING FOR DUPLICATES IN TCONST 
len(set(rating["tconst"]))
# Out:
# 73856

# %%
#DUPLICATE DATA FRAME OF MERGE BETWEEN MOVIES AND GROSS
df_gross_movies1 = df_gross_movies.copy()

# %%
#DUPLICATE DATA FRAME OF RATING
rating1 = rating.copy()

# %% [markdown]
# ### Merge Df_gross_movies with Data Frame of Rating

# %%
#MERGE DATA FRAME DF_GROSS_MOVIES1 WITH RATING1 BY TCONST
df_gross_movies_raiting = pd.merge(df_gross_movies1,rating1, on = "tconst")
df_gross_movies_raiting
# Out:
#          tconst                    primary_title  \
# 0     tt0315642                            Wazir
# 1     tt0337692                      On the Road
# 2     tt0359950  The Secret Life of Walter Mitty
# 3     tt0365907      A Walk Among the Tombstones
# 4     tt0369610                   Jurassic World
# ...         ...                              ...
# 2544  tt8331988                  The Chambermaid
# 2545  tt8404272           How Long Will I Love U
# 2546  tt8427036                  Helicopter Eela
# 2547  tt9078374                      Last Letter
# 2548  tt9151704        Burn the Stage: The Movie
#
#                        original_title  start_year  runtime_minutes  \
# 0                               Wazir        2016            103.0
# 1                         On the Road        2012            124.0
# 2     The Secret Life of Walter Mitty        2013            114.0
# 3         A Walk Among the Tombstones        2014            114.0
# ...

# %%
#CHECKING FOR DUPLICATES IN TCONST 
len(set(df_gross_movies_raiting["tconst"]))
# Out:
# 2549

# %%
df_gross_movies_raiting.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'studio', 'domestic_gross',
#        'foreign_gross', 'year', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
#DROP COLUMN START_YEAR
df_gross_movies_raiting.drop(columns = ['original_title', 'start_year', 'runtime_minutes'], inplace = True)

# %%
#PRINT INFO OF FILE
df_gross_movies_raiting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2549 entries, 0 to 2548
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          2549 non-null   object
#  1   primary_title   2549 non-null   object
#  2   genres          2548 non-null   object
#  3   studio          2546 non-null   object
#  4   domestic_gross  2532 non-null   float64
#  5   foreign_gross   1532 non-null   object
#  6   year            2549 non-null   int64
#  7   averagerating   2549 non-null   float64
#  8   numvotes        2549 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 199.1+ KB

# %% [markdown]
# # Final Dataframe
#
# ### This DataFrame now is all clean and ready to work for our future recomendations.

# %%
#FINAL MERGE OF ALL DATA FRAMES IN ONE

df_gross_movies_raiting
# Out:
#          tconst                    primary_title                   genres  \
# 0     tt0315642                            Wazir       Action,Crime,Drama
# 1     tt0337692                      On the Road  Adventure,Drama,Romance
# 2     tt0359950  The Secret Life of Walter Mitty   Adventure,Comedy,Drama
# 3     tt0365907      A Walk Among the Tombstones       Action,Crime,Drama
# 4     tt0369610                   Jurassic World  Action,Adventure,Sci-Fi
# ...         ...                              ...                      ...
# 2544  tt8331988                  The Chambermaid                    Drama
# 2545  tt8404272           How Long Will I Love U                  Romance
# 2546  tt8427036                  Helicopter Eela                    Drama
# 2547  tt9078374                      Last Letter            Drama,Romance
# 2548  tt9151704        Burn the Stage: The Movie        Documentary,Music
#
#          studio  domestic_gross foreign_gross  year  averagerating  numvotes
# ...

# %%
#SAVING MERGE OF DATA FRAME AS A MAIN_DATA.CSV FILE

df_gross_movies_raiting.to_csv("/Users/christopherfreyre/Documents/Academy Xi/Project_one/main_data.csv")
